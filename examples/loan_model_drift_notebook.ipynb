# %% [markdown]
# # DriftWatch Loan Model Demo
#
# This notebook summarizes the January-to-August drift scenario used in DriftWatch.

# %%
print('Run examples/loan_model_demo.py for the full API-driven demo.')
